# %%
# !pip install google_play_scraper
# Out:
# ...
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.0.3-py3-none-any.whl size=24394 sha256=e968128ec0ce7214fb34bbbb0a847f440949347aed258e35fd364532894163a0
#   Stored in directory: c:\users\clemence\appdata\local\pip\cache\wheels\b0\17\bf\a06f635b5343780c7ec2b554dccc3aa4cf3ead928304088ad5
# Successfully built google-play-scraper
# ...

# %%
from google_play_scraper import app

# %%
from google_play_scraper import Sort, reviews_all

# %%
reviews = reviews_all('com.inventureaccess.safarirahisi',#app id
                     lang = 'en',
                     country = 'ke',
                    
                     )

# %%
import pandas as pd
import numpy as np

# %%
reviews
# Out:
# [{'reviewId': 'gp:AOqpTOFsR1XdcAr2YL4yky4KoXcYClkEU_kx2d8P618B1Q9Ceg1X5AU6W6XsPj6-36DBi9PjRSD4VVz3dGEh_Pk',
#   'userName': 'Annah Kasyoki',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJzpzfroiRM2MmyjZxF-If6DVhOOCWskKLPtJeAb=mo',
#   'content': 'The best app ever. Love it👌',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '7.108.0',
#   'at': datetime.datetime(2022, 4, 2, 20, 31, 1),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'gp:AOqpTOFOVZmdBwcXY24RFoDMz9QVNNEOha6y3nXURhr0lX7Qnwo3CWlLTkPbJH_veNVFD5Pjvbq3Bqn-G0nd3jQ',
#   'userName': 'Santa Jane',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJyTftz3QT49lwK-bFSfHho299PUHGPXRbwpNEf-=mo',
#   'content': 'Quick service not many questions paying rates are reasonable',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '7.109.0',
#   'at': datetime.datetime(2022, 4, 2, 19, 52, 25),
#   'replyContent': None,
#   'repliedAt': None},
# ...

# %%
df_tala = pd.DataFrame(np.array(reviews),columns=['reviews']) #put reviews into pandas dataframe

# %%
df_tala = df_tala.join(pd.DataFrame(df_tala.pop('reviews').tolist()))

# %%
df_tala.head() #view the first 5 rows
# Out:
#                                             reviewId        userName  \
# 0  gp:AOqpTOFsR1XdcAr2YL4yky4KoXcYClkEU_kx2d8P618...   Annah Kasyoki
# 1  gp:AOqpTOFOVZmdBwcXY24RFoDMz9QVNNEOha6y3nXURhr...      Santa Jane
# 2  gp:AOqpTOHvh221Vukg67u6mAk2avhErGj4VdcUSvxeQfW...   Maggie Akinyi
# 3  gp:AOqpTOFy1y2am2ihuWB0zZMdR2hjAM3q5pibGkWkoBC...  Millicent Rian
# 4  gp:AOqpTOElcamSV65eL9NRTy-WVvKFK-fhXMHblNGL5Ws...    Sophia Temko
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AATXAJ...
# 1  https://play-lh.googleusercontent.com/a/AATXAJ...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a/AATXAJ...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0                        The best app ever. Love it👌      5              0
# 1  Quick service not many questions paying rates ...      5              0
# ...

# %%
df_tala.to_csv('Reviews.csv', index= False) #save to pdf

# %%
# Out:
# []

# %%
# Out:
# []
